# %%
import pandas as pd

df = pd.read_pickle('dset-mnist_alg-pfedme_C-0.5_B-20_T-200_E-1_device-gpu_W-200_seed-0_lr-0.3_noisy_frac-0.0_beta-1.0_lamda-1.0.pkl')
print(df)
# Out:
# (array([2.304451  , 1.4314728 , 0.94483876, 0.50014913, 0.37839398,
#        0.26287323, 0.17038631, 0.15068899, 0.10376501, 0.08977219,
#        0.14974736, 0.1338303 , 0.11754742, 0.17904696, 0.14713575,
#        0.1071981 , 0.15007654, 0.1190695 , 0.14424802, 0.08019989,
#        0.08807213, 0.15435433, 0.08160561, 0.22992168, 0.12824337,
#        0.12039444, 0.14550751, 0.1426756 , 0.11902262, 0.0797598 ,
#        0.13065796, 0.14575374, 0.12618522, 0.07721354, 0.13379231,
#        0.09095097, 0.09215169, 0.09980502, 0.15498048, 0.10054401,
#        0.0944042 , 0.11029742, 0.09796803, 0.08255038, 0.17405212,
#        0.12897514, 0.15165143, 0.14703582, 0.11760445, 0.12826416,
#        0.14376001, 0.15752034, 0.16792317, 0.13074379, 0.08014284,
#        0.13645245, 0.13040207, 0.14780846, 0.11226589, 0.10593854,
#        0.12195343, 0.09112801, 0.12610334, 0.10528014, 0.1541522 ,
#        0.07181624, 0.0831885 , 0.13154987, 0.09921874, 0.156771  ,
# ...

# %%
import torch

# %%
torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# device(type='cpu')

# %%
# !nvidia-smi
# Out:
# Fri May 23 10:36:40 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.07                 Driver Version: 566.07         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4050 ...  WDDM  |   00000000:C4:00.0 Off |                  N/A |
# | N/A   41C    P3             11W /   65W |       0MiB /   6141MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
